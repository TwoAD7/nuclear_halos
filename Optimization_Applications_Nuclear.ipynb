# %% [markdown]
# <h1><center>Applications of Optimization in Nuclear Physics</center></h1>
#
# ---

# %% [markdown]
# In discussing applications of optimizations models in nuclear physics, one can take either a well beaten path and make it wider, or create a new path. If one looks at reaction studies, in my preliminary understanding of the topic, one is looking for fission/fusion products, coincidences in gamma (photon) detection, and either heavy or light nuclei residues that are left after the reaction. In life time measurement of exotic nuclei, one utilizes the shell model - similar to the atomic shell model - to describe excited states of the nucleons. For example, an excited nucleon can become excited by an interaction with a incoming particle beam with some momentum wave function, and "jump" into an exctied state. Upon excitation, the nucleon becomes de-excited and emmits a gamma particle (photon) which is detected by a detector. This is a sliver of what the field of nuclear physics entails, and put very simply in my rudimentaty understanding of these two fields of research. It would be safe to suspect that one can apply optimization methods such as machine learning methods or neural networks to do two things: classify data or create a regression model. Of course, machine learning is not the only approach as one can also utilize Bayesian optimization models for quantum mechanical systems due to the probabilistic nature of quantum mechanics. One cannot forget about the uncertainties in such experiments and the several attempts and models developed to evaluate these uncertainties to minimize error in a global calculation.

# %% [markdown]
# To provide an example of an appliation of an optimization method, I will discuss a study I carried out my senior year in my undergraduate studies that concerned itself with machine learning. The premise of the study was to utilize machine learning methods, particularly neural networks, to create a regression model from simulated data given a target variable and input variables. The target variable was the "true" particle jet transvere momentum ($p_{T}$) and the input variales were detector jet ($p_{T}$), and the pseudorapidity, $\eta$, which is an angle measurement telling me how orthogonal I am to the beam axis. The goal was to apply this regression model to experiment data to "predict" the "true" partile jet $p_{T}$ distribution. An example of input variables is seen below:

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

# %%
im = Image.open("InputVariables.png") #create image object 
pix = im.load()                  
plt.figure(figsize=(13,13))
plt.imshow(im)
plt.show()

# %% [markdown]
# The above figure demonstrates the particle jet $p_{T}$ as **_pJetPt_** (true level) to the detector jet $p_{T}$ as **_dJetPtMtx_**  (detector level). The deviation is due to finite detector resolution, which implies there is some sort of regression required. Of course, one doesn't need to perform a regression to arrive at the true particle level as one can use a direct physics approach and create a model based on statistical methods such as Bayesian optimization/regression.

# %% [markdown]
# Below, you will find an example (out of many) of a regression model that utilized a Multilayer Perceptron (MLP) model with particular tuning parameters.

# %%
im = Image.open("MLP1.png") #create image object 
pix = im.load()                  
plt.figure(figsize=(13,13))
plt.imshow(im)
plt.show()

# %% [markdown]
# This is a field of nuclear physics that concerns itself with multiplicity measurements of particles in proton-proton collisions to study something known as the Collins Mechanism. Due to the large data sets and statistics in experiments such as these, it is essential to have an efficient and accurate optimization model to compare with theory calculations. This is a subfield in nuclear phsyics that is currently being studied by many physicist, and as our computing prowess increases, one is beginning to see an emergence of models such as these. Besides discovery, machine learning can also be applied to nuclear energy by studying the dynamics of fission reactions, power generated by a nuclear reactor, and the stability of the reactions taking place within the reactor itself. In better understanding the dynamics and properties of a fission reaction, one can create better fuel for the reactor and modify certain conditions of the reactor to get optimal power output. That being said, stability is also crucial in nuclear reactors as having a nuclear meltdown is a disaterous event that can have negative implications for generations.

# %% [markdown]
# In my own research domain, I can apply optimization methods such as neural networks, support vector machines, decision trees, bayesian statistics, etc. to better understand nuclear structure and reactions. For example, machine learning can be applied to analysis efforts in experiements that are poised to better understand nuclear structure. By doing so, one can glean a better picture of nuclear matter which contributes to the equation of state for nuclear systems which adds the the cummulative understanding of our universe. At the moment, I am looking at weakly bound nuclei, that due to quantum effects, are allowed to "tunnel" into the center of the nucleus. Such systems are said to contain "nuclear halos" due to the weakly bound neutron that is "outside" the nucleus. I am currently investigating how to apply optimization methods to spectroscopy studies of rare isotopes to better understand the dynamics and structure of rare isotpes. This opportunity will be made possible by the Facility for Rare Isotope Beams (FRIB) here at MSU, which will be functional in about two years as the world's most powerful rare isotope beam.

# %% [markdown]
# <h2>References</h2>
#
# <ul>
#   <li>Stefan Schmitt. Data Unfolding Methods in High Energy Physics.DOI: 10.1051/epjconf/201713711008 </li> <!--unfolding (regression) models-->
#   <li> A Ekström et al 2019 J. Phys. G: Nucl. Part. Phys. 46 095101</li> <!--bayesian optimization-->
#   <li>Volker Blobel. Unfolding Methods in Particle Physics arxiv:1104.2962.pd</li> <!--unfolding-->
#   <li> I.-H. Bae et al., "Estimation of the Power Peaking Factor in a Nuclear Reactor Using Support Vector Machines and Uncertainty Analysis," Nucl. Eng. Technol. 41, 1181 (2009) </li> <!--SVM for nuclear energy-->
# </ul>
